# %%
import pandas as pd

# %%
#eb = Entertainer - Basic Info
#ebt = Entertainer - Breakthrough Info
#el = Entertainer - Last work Entertainer Info

# %%
eb = pd.read_excel('Entertainer - Basic Info.xlsx')

# %%
eb.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
ebt = pd.read_excel('Entertainer - Breakthrough Info.xlsx')

# %%
ebt.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
el = pd.read_excel('Entertainer - Last work Info.xlsx')

# %%
el.head()
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN

# %%
#concating eb and ebt

# %%
first=pd.concat([eb,ebt],axis=1)

# %%
first.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
#concating first and el

# %%
second=pd.concat([first,el],axis=1)

# %%
second.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
final_data=second

# %%
final_data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...

# %%
#saving to excel file

# %%
entertainer_analysis='final_data.xlsx'

# %%
final_data.to_excel(entertainer_analysis)

# %%
final_data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year      Entertainer  \
# 0            Adele                    F        1988            Adele
# 1   Angelina Jolie                    F        1975   Angelina Jolie
# 2  Aretha Franklin                    F        1942  Aretha Franklin
# 3      Bette Davis                    F        1908      Bette Davis
# 4      Betty White                    F        1922      Betty White
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# ...
